# %%
def run_diary_exercise():
    with open("diary.txt","w") as f:
        f.write("Day 1: Started python learning. \n")
        

        try:
            with open("diary.txt","r") as f:
                print(f.read())
        except FileNotFoundError:
                print("Diary file is currently missing")
        try:
             with open("missing.txt", "r") as f:
                  content = f.read()
                  print(content)
        except FileNotFoundError:
             print("Safe exit: missing.txt not found")

run_diary_exercise()
# Out:
# Safe exit: missing.txt not found

# %%
import

# %%
def run_diary_exercise():
    with open("notes.txt","a") as f:
        f.write(input("enter your diary entry:") + "\n")

        try:
            with open("notes.txt", "r") as f:
                print(f.read().strip())
        except FileNotFoundError:
            print("Error: Notes file not found:")

        try:
            with open(input("enter the filename to read:"), "r") as f:
                 print(f.read().strip())
        except FileNotFoundError:
            print("error: the specified  file was not found.")
            


run_diary_exercise()
# Out:
# amit
# pratyush
# pratyush
# patyush
# error: the specified  file was not found.

# %%
def save_note():
    note = input(" Type a note to save:")
    with open("notes.txt", "")
