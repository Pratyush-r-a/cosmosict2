# %% [markdown]
# import pandas as pd
#
# data = {
#     "name": ["pratyush", "amit", "bipul"],
#     "age": [25, 35, 23]
# }
#
# df = pd.DataFrame(data)
#
# print(df)
# print("Average Age:", df["age"].mean())

# %%
import requests
response = requests.get("https:/api.github.com")
print(response.status_code)
print(response.json())
