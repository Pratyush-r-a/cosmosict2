# %%
import pandas as pd

data = {
    "name": ["pratyush", "amit", "bipul","munal","kaushal"],
    "score": [53, 43, 90, 72, 62]
}

df = pd.DataFrame(data)

df["passed"] = df["score"] >= 50
print(df)
df["score"].max
# Out:
#        name  score  passed
# 0  pratyush     53    True
# 1      amit     43   False
# 2     bipul     90    True
# 3     munal     72    True
# 4   kaushal     62    True
# <bound method Series.max of 0    53
# 1    43
# 2    90
# 3    72
# 4    62
# Name: score, dtype: int64>
